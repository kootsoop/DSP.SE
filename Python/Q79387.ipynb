# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal

T = 1024
Ton = 100

x = np.random.normal(0,0.1, T)

for t in np.arange(Ton,T):
    x[t] = x[t] + 10*(1-np.exp(-(t-Ton)/50))

dxdt = np.gradient(x)
median_dxdt = signal.medfilt(dxdt,31)

mx = median_dxdt.max()
ix = np.argmax(median_dxdt)

plt.figure(1)
plt.plot(x)

plt.figure(2)
plt.plot(dxdt)

plt.figure(3)
plt.plot(median_dxdt)
plt.plot(ix,mx,'r.')

# %%
import scipy.optimize

def F(coeffs):
    T = len(x)
    return np.abs(x-coeffs[0]*(1-np.exp(-(t-coeffs[1])/coeffs[2])))
x = scipy.optimize.broyden1(F, [10,100,50], f_tol=1e-14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-0f594a4f4108> in <module>
#       4     T = len(x)
#       5     return np.abs(x-coeffs[0]*(1-np.exp(-(t-coeffs[1])/coeffs[2])))
# ----> 6 x = scipy.optimize.broyden1(F, [10,100,50], f_tol=1e-14)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/nonlin.py in broyden1(F, xin, iter, alpha, reduction_method, max_rank, verbose, maxiter, f_tol, f_rtol, x_tol, x_rtol, tol_norm, line_search, callback, **kw)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/nonlin.py in nonlin_solve(F, x0, jacobian, iter, verbose, maxiter, f_tol, f_rtol, x_tol, x_rtol, tol_norm, line_search, callback, full_output, raise_exception)
#     316         # Line search, or Newton step
#     317         if line_search:
# --> 318             s, x, Fx, Fx_norm_new = _nonlin_line_search(func, x, Fx, dx,
#     319                                                         line_search)
#     320         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/nonlin.py in _nonlin_line_search(func, x, Fx, dx, search_type, rdiff, smin)
#     395                                              xtol=1e-2, amin=smin)
#     396     elif search_type == 'armijo':
# --> 397         s, phi1 = scalar_search_armijo(phi, tmp_phi[0], -tmp_phi[0],
#     398                                        amin=smin)
#     399
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py in scalar_search_armijo(phi, phi0, derphi0, c1, alpha0, amin)
#     701
#     702     """
# --> 703     phi_a0 = phi(alpha0)
#     704     if phi_a0 <= phi0 + c1*alpha0*derphi0:
#     705         return alpha0, phi_a0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/nonlin.py in phi(s, store)
#     378         if s == tmp_s[0]:
#     379             return tmp_phi[0]
# --> 380         xt = x + s*dx
#     381         v = func(xt)
#     382         p = _safe_norm(v)**2
#
# ValueError: operands could not be broadcast together with shapes (3,) (1024,)
