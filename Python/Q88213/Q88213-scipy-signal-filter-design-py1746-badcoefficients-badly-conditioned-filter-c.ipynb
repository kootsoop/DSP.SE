# %%
import numpy as np
import control as ct

sys = ct.tf([3.553e-15, -.1642, -.1243, -.00161, 9.121e-17],
            [1, 1.825, 2.941, .03508, .01522, -1.245e-15])
0
ct.nyquist(sys, indent_radius=1e-16, omega=np.arange(0,100,0.0001))
# Out:
# 2
