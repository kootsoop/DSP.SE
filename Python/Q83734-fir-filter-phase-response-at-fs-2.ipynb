# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

N = 64
frequencies = np.linspace(0,1,N)
phase = np.linspace(0,-0.6,N)

plt.figure(1)
plt.plot(phase)

h =  signal.firls(9, frequencies, np.exp(1j*phase) )

plt.figure(2)
plt.plot(np.real(h))
plt.plot(np.imag(h))

w, resp = signal.freqz(h)

plt.figure(3)
plt.plot(w,np.angle(resp*np.exp(1j*w*4)))

plt.figure(4)
plt.plot(w,np.abs(resp*np.exp(1j*w*4)))

# %%
plt.plot(np.real(np.fft.ifft(np.exp(1j*phase))))
plt.plot(np.imag(np.fft.ifft(np.exp(1j*phase))))
