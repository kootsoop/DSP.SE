# %%
import numpy as np
import matplotlib.pyplot as plt

fft_db = np.random.random(100)*100 - 130 
fft_db[80:100] = -130

fft_db_flip = np.flip(fft_db)

requested_value = len(fft_db) - np.argmax(fft_db_flip > -60) - 1

plt.plot(fft_db)
plt.plot(requested_value, fft_db[requested_value],'r.')
plt.plot([0,100],[-60,-60],'g:')

# %%
fft_db
# Out:
# array([ -44.25430221,  -38.42791286,  -46.55934903, -110.49588785,
#         -62.18862107, -123.76767808,  -70.5685835 ,  -44.26756807,
#        -113.36530391,  -83.79233758,  -99.28759639,  -90.86791302,
#         -47.15309694,  -95.79360956,  -86.25310807,  -37.48157234,
#        -115.31792336,  -93.98956085,  -32.55395864, -122.04369464,
#        -118.18504236,  -55.04743609,  -42.83423364, -107.50475763,
#         -41.67801731,  -91.8137142 ,  -55.21996355,  -69.76492143,
#         -88.64526858,  -96.27996141,  -98.74871948,  -30.29293445,
#         -46.67510354,  -82.88305299,  -32.16025557,  -47.7202765 ,
#         -49.74458878,  -74.59952932,  -60.90562622, -102.04371621,
#         -54.38780246,  -32.1478468 ,  -51.13374266,  -61.15930763,
#         -37.34593145,  -83.50912798,  -33.31087345, -106.48676504,
#        -103.2262555 ,  -34.18773194,  -57.21620011, -119.1245174 ,
#         -99.86531567,  -36.07142488,  -95.57016154,  -63.97774299,
#         -80.54723962,  -50.82847793,  -61.11904384, -104.85073292,
#         -83.27455908,  -64.7300107 ,  -68.19116031,  -87.32743325,
#        -111.46670794,  -66.21142477, -125.33003253,  -94.56831432,
#        -109.03515853,  -95.27640694,  -40.16638562, -125.19123104,
#        -114.11210335,  -37.16099635, -116.7697171 ,  -52.20655864,
#        -116.70879257,  -97.1449703 ,  -37.89654332,  -85.89172916,
#        -130.        , -130.        , -130.        , -130.        ,
#        -130.        , -130.        , -130.        , -130.        ,
#        -130.        , -130.        , -130.        , -130.        ,
#        -130.        , -130.        , -130.        , -130.        ,
#        -130.        , -130.        , -130.        , -130.        ])
